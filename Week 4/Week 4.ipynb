# %% [markdown]
# Data ingestion notebook using pandas — build a Jupyter notebook that loads CSV/JSON/text data, handles missing values, normalizes column names, performs simple EDA (head(), describe(), value_counts()), and exports a cleaned CSV.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
RAW_DIR = Path("./data/raw")
PROCESSED_DIR = Path("./data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

FILE_NAME = "tmdb_movies.csv"   # change this, not your code

# %%
def load_data(file_path: Path) -> pd.DataFrame:
    ext = file_path.suffix.lower()

    if ext == ".csv":
        return pd.read_csv(file_path)

    if ext == ".json":
        return pd.read_json(file_path)

    if ext in [".txt", ".tsv"]:
        return pd.read_csv(file_path, sep=None, engine="python")

    raise ValueError(f"Unsupported format: {ext}")


df = load_data(RAW_DIR / FILE_NAME)

# %%
df.head()
# Out:
#    id          title                            genre release_date  \
# 0   1  Movie Title 1  Science Fiction, Comedy, Horror   1957-01-01
# 1   2  Movie Title 2             Documentary, Romance   1999-01-01
# 2   3  Movie Title 3          Science Fiction, Action   1941-01-01
# 3   4  Movie Title 4         Comedy, Drama, Adventure   1961-01-01
# 4   5  Movie Title 5                  Comedy, Romance   1969-01-01
#
#    release_year     budget       revenue  runtime  vote_average  vote_count  \
# 0          1957   36972721  1.306928e+08      123      4.496790        9221
# 1          1999   96359319  2.947975e+08      146      5.803306        4592
# 2          1941  135172742  1.048409e+08      168      2.710639        7146
# 3          1961  129049379  1.535585e+08      134      5.631398        8363
# 4          1969  151390401  1.008291e+08      116      4.245862        9487
#
#   production_country
# 0            Germany
# 1              China
# 2              Japan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  100 non-null    int64
#  1   title               100 non-null    object
#  2   genre               100 non-null    object
#  3   release_date        100 non-null    object
#  4   release_year        100 non-null    int64
#  5   budget              100 non-null    int64
#  6   revenue             100 non-null    float64
#  7   runtime             100 non-null    int64
#  8   vote_average        100 non-null    float64
#  9   vote_count          100 non-null    int64
#  10  production_country  100 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 8.7+ KB

# %%
def clean_column_names(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
        .str.replace(r"[^\w]", "", regex=True)
    )
    return df


df = clean_column_names(df)
df.head()
# Out:
#    id          title                            genre release_date  \
# 0   1  Movie Title 1  Science Fiction, Comedy, Horror   1957-01-01
# 1   2  Movie Title 2             Documentary, Romance   1999-01-01
# 2   3  Movie Title 3          Science Fiction, Action   1941-01-01
# 3   4  Movie Title 4         Comedy, Drama, Adventure   1961-01-01
# 4   5  Movie Title 5                  Comedy, Romance   1969-01-01
#
#    release_year     budget       revenue  runtime  vote_average  vote_count  \
# 0          1957   36972721  1.306928e+08      123      4.496790        9221
# 1          1999   96359319  2.947975e+08      146      5.803306        4592
# 2          1941  135172742  1.048409e+08      168      2.710639        7146
# 3          1961  129049379  1.535585e+08      134      5.631398        8363
# 4          1969  151390401  1.008291e+08      116      4.245862        9487
#
#   production_country
# 0            Germany
# 1              China
# 2              Japan
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# id                    0
# title                 0
# genre                 0
# release_date          0
# release_year          0
# budget                0
# revenue               0
# runtime               0
# vote_average          0
# vote_count            0
# production_country    0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#                 id          title      genre release_date  release_year  \
# count   100.000000            100        100          100     100.00000
# unique         NaN            100         69           59           NaN
# top            NaN  Movie Title 1  Adventure   1983-01-01           NaN
# freq           NaN              1          8            4           NaN
# mean     50.500000            NaN        NaN          NaN    1980.89000
# std      29.011492            NaN        NaN          NaN      24.03066
# min       1.000000            NaN        NaN          NaN    1940.00000
# 25%      25.750000            NaN        NaN          NaN    1961.00000
# 50%      50.500000            NaN        NaN          NaN    1981.00000
# 75%      75.250000            NaN        NaN          NaN    1999.25000
# max     100.000000            NaN        NaN          NaN    2024.00000
#
#               budget       revenue     runtime  vote_average   vote_count  \
# ...

# %%
for col in df.select_dtypes(include="object"):
    print(f"\n{col}")
    print(df[col].value_counts().head())
# Out:
# title
# title
# Movie Title 1    1
# Movie Title 2    1
# Movie Title 3    1
# Movie Title 4    1
# Movie Title 5    1
# Name: count, dtype: int64
#
# genre
# genre
# Adventure      8
# Horror         5
# Action         3
# Documentary    3
# Drama          3
# Name: count, dtype: int64
#
# release_date
# release_date
# 1983-01-01    4
# 2007-01-01    3
# 2022-01-01    3
# 1964-01-01    3
# 1952-01-01    3
# Name: count, dtype: int64
#
# production_country
# production_country
# Canada            16
# India             14
# France            14
# China             13
# United Kingdom    13
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
def safe_to_numeric(series: pd.Series) -> pd.Series:
    try:
        return pd.to_numeric(series)
    except (ValueError, TypeError):
        return series


for col in df.columns:
    df[col] = safe_to_numeric(df[col])

# %%
OUTPUT_FILE = PROCESSED_DIR / "customers_clean.csv"
df.to_csv(OUTPUT_FILE, index=False)

print("Exported:", OUTPUT_FILE)
# Out:
# Exported: data\processed\customers_clean.csv

# %% [markdown]
# The data was clean from its source.
